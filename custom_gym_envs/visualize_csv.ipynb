# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('/home/zsufiyan/Documents/openai/data/PPOv2_Ant-v2:100000_lr:0.00025_lrd:False_g:0.98_ns:512_mbs:256_epo:4_eps:0.1_c1:0.5_c2:0.01_cvl:False_mgn:0.5_gae:True_lam:0.95_hd:64_lstd:0.0_tef:500_ee:10_tmsf:50000000_d:cuda/seed0/csv/eval_data.csv')
data2 = pd.read_csv('/home/zsufiyan/Documents/openai/data/PPOv2_AntEnv-v1:100000_lr:0.00025_lrd:False_g:0.98_ns:512_mbs:256_epo:4_eps:0.1_c1:0.5_c2:0.01_cvl:False_mgn:0.5_gae:True_lam:0.95_hd:64_lstd:0.0_tef:500_ee:10_tmsf:50000000_d:cuda/seed0/csv/eval_data.csv')

# Assume you want to plot 'column1' on the x-axis and 'column2' on the y-axis
plt.plot(data['num_time_steps'], data['average_return'], label='Ant-v2')
plt.plot(data2['num_time_steps'], data2['average_return'], label='AntEnv-v1(Broken Limb)')
plt.xlabel('Number of Time Steps')
plt.ylabel('Average Return')
plt.title('Average Return over Time Steps')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'num_time_steps', 'num_updates', 'num_epoch_updates',
#        'num_mini_batch_updates', 'num_samples', 'average_return', 'real_time'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data2 = pd.read_csv('/home/zsufiyan/Documents/openai/data/PPOv2_AntEnv-v1:100000_lr:0.00025_lrd:False_g:0.98_ns:512_mbs:256_epo:4_eps:0.1_c1:0.5_c2:0.01_cvl:False_mgn:0.5_gae:True_lam:0.95_hd:64_lstd:0.0_tef:500_ee:10_tmsf:50000000_d:cuda/seed0/csv/eval_data.csv')
# Assume you want to plot 'column1' on the x-axis and 'column2' on the y-axis
plt.plot(data2['num_time_steps'], data2['average_return'])
plt.xlabel('Number of Time Steps')
plt.ylabel('Average Return')
plt.title('Average Return over Time Steps')
plt.grid(True)
plt.show()
